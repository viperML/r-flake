# %%
library(magrittr)
library(ggplot2)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
beaver <- beaver1

beaver <- beaver %>%
    select(time, temp)

head(beaver)
# Out:
#   time temp
# 1 840  36.33
# 2 850  36.34
# 3 900  36.35
# 4 910  36.42
# 5 920  36.55
# 6 930  36.69

# %%
ggplot(data=beaver, aes(x=time, y=temp)) + geom_point() + geom_rug()
# Out:
# plot without title
